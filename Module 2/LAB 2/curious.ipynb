# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.pylab as pylab
import seaborn as sns

# Cause plots to be displayed in the notebook:
# %pylab inline
# %matplotlib inline
# Out:
# Bad key "text.kerning_factor" on line 4 in
# C:\Users\britn\anaconda3\envs\iod\lib\site-packages\matplotlib\mpl-data\stylelib\_classic_test_patch.mplstyle.
# You probably need to get an updated matplotlibrc file from
# https://github.com/matplotlib/matplotlib/blob/v3.1.3/matplotlibrc.template
# or from the matplotlib source distribution
# Populating the interactive namespace from numpy and matplotlib

# %%
house_hold = pd.read_csv("../../DATA/Family_Income_and_Expenditure.csv")

# %%
house_hold.head()
# Out:
#    Total Household Income Region  Total Food Expenditure  \
# 0                  480332    CAR                  117848
# 1                  198235    CAR                   67766
# 2                   82785    CAR                   61609
# 3                  107589    CAR                   78189
# 4                  189322    CAR                   94625
#
#   Main Source of Income  Agricultural Household indicator  \
# 0         Wage/Salaries                                 0
# 1         Wage/Salaries                                 0
# 2         Wage/Salaries                                 1
# 3         Wage/Salaries                                 0
# 4         Wage/Salaries                                 0
#
#    Bread and Cereals Expenditure  Total Rice Expenditure  Meat Expenditure  \
# 0                          42140                   38300             24676
# 1                          17329                   13008             17434
# ...

# %%
house_hold.shape
# Out:
# (41544, 60)

# %%
house_hold.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 41544 entries, 0 to 41543
# Data columns (total 60 columns):
#  #   Column                                         Non-Null Count  Dtype
# ---  ------                                         --------------  -----
#  0   Total Household Income                         41544 non-null  int64
#  1   Region                                         41544 non-null  object
#  2   Total Food Expenditure                         41544 non-null  int64
#  3   Main Source of Income                          41544 non-null  object
#  4   Agricultural Household indicator               41544 non-null  int64
#  5   Bread and Cereals Expenditure                  41544 non-null  int64
#  6   Total Rice Expenditure                         41544 non-null  int64
#  7   Meat Expenditure                               41544 non-null  int64
#  8   Total Fish and  marine products Expenditure    41544 non-null  int64
# ...

# %%
sns.histplot(house_hold['Total Household Income']);
#This distribution is called skewed right if, as in the histogram below, 
#the right tail (larger values) is much longer than the left tail (small values).

# %%
mean_income = house_hold['Total Household Income'].mean()
print('Total Household Mean Income:', mean_income)
# Out:
# Total Household Mean Income: 247555.58480165608

# %%
#When you calculate the mean income as you did previously (247,555.58), this mean is an average of all such individual household income values in your dataset. 
#Each household might have a different income, some higher and some lower than this average. 
#The purpose of calculating the mean is to find a central or typical value that represents the entire dataset.

# %%
#Take 10 samples, but with a sample size of 5.

# %%
def calculate_sample_mean(df, column_name, N = 10, sample_size = 5):
    '''
    df:DataFrame
    column_name:String,column_name
    N:Number of samples
    sample_size: Size of sample for each sample
    '''
    sample_mean_list = []
    
    for i in range(N):
        df_sample = df.sample(n=sample_size)
        sample_mean = df_sample[column_name].mean()
        sample_mean_list.append(sample_mean)
    
    return sample_mean_list

# %%
#df: This is the DataFrame from which the samples will be drawn.

#column_name: A string specifying the name of the column in df for which the mean is to be calculated.

#N: The number of samples to be drawn from the DataFrame. It defaults to 10 if not specified.

#sample_size: The size of each sample, i.e., how many rows each sample will contain. It defaults to 5 if not specified.

#sample_mean_list = [] is an empty list to store the mean of each sample

#The for loop for i in range(N): will iterate N times to create N different samples.

#df_sample = df.sample(n=sample_size): Inside the loop, a sample of size sample_size is drawn from the DataFrame df using the sample method. 
#This is done without replacement by default.

#sample_mean = df_sample[column_name].mean(): The mean of the specified column for this sample is calculated.

#sample_mean_list.append(sample_mean): This mean is then appended to the list sample_mean_list.

#return sample_mean_list: After the loop finishes, the function returns the list of sample means.

#This can help in understanding how the sample mean varies from sample to sample and can be used to illustrate 
#the Central Limit Theorem, a key concept in statistics.

# %%
#In simple terms, creating an empty list in your code is like starting with an empty basket when you go apple picking. 
#As you walk through the orchard (or loop through your data), each time you pick an apple (calculate a sample mean), 
#you put it in your basket (add it to the list). By the end of your trip (when the loop ends), 
#you have a basket full of apples (a list full of sample means) that you can then take back home (return from the function). 
#This makes it easy to keep track of all the apples you've picked (all the means you've calculated) in one place.

# %%
def visual_sample_mean(population_mean,sample_mean_list):
    '''
    population mean: mean of entire population
    sample_mean_list: list of sample mean
    '''
    
    sample_mean = np.mean(sample_mean_list)
    
    ax= sns.distplot(sample_mean_list);
    
    #plot a vertical line for population mean and sample mean
    ax.axvline(population_mean, color = 'black', linestyle ='solid', lw=1)
    ax.axvline(sample_mean, color= 'red', linestyle = 'dashed', lw = 1)
    
    plt.xlabel('Mean of Samples')
    plt.ylabel('Frequency')
               
    plt.show()

# %%
#The visual_sample_mean function in your code is designed to visualize the distribution of sample means and compare it to the population mean. 

#population_mean: This is the mean (average) of the entire population.

#sample_mean_list: This is a list of sample means, presumably calculated from several different samples of the population.

#sample_mean = np.mean(sample_mean_list) calculates the average of all the sample means in sample_mean_list. 
#This average is itself a point estimate of the population mean and demonstrates the central tendency of your sample means.

#ax = sns.distplot(sample_mean_list); uses Seaborn's distplot function to create a histogram that shows the distribution of your sample means. 
#The plot will give you a visual representation of how these sample means are spread out or clustered.

#ax.axvline(population_mean, color='black', linestyle='solid', lw=1): adds a solid black vertical line at the position of the population mean. 
#It serves as a reference to compare where the population mean lies relative to the distribution of sample means.

#ax.axvline(sample_mean, color='red', linestyle='dashed', lw=1): adds a dashed red vertical line at the average of the sample means. 
#This shows how close your average sample mean is to the population mean.

#plt.xlabel('Mean of Samples') and plt.ylabel('Frequency'): These lines label the x-axis and y-axis of the plot.

#plt.show(): This line displays the plot. If you are using a Jupyter Notebook, this will render the plot inline.

# %%
sample_mean_list = calculate_sample_mean(house_hold, 'Total Household Income', N=10, sample_size =5)

# %%
#calculate_sample_mean(...): This is the function you've defined earlier. Its purpose is to calculate the means of several samples taken from a given DataFrame.

#house_hold: This is the DataFrame being passed to the function. The function will take random samples from this DataFrame. 
#It's assumed that house_hold contains data about household incomes.

#'Total Household Income': This is a string representing the name of the column in house_hold for which you want to calculate the sample means. 
#The function will look at this specific column to compute the means.
    
#N=10: This specifies that you want to take 10 different samples from the DataFrame. 
#So, the function will repeat its sampling process 10 times.

#sample_size=5: This indicates the size of each sample to be 5. 
#That means, in each of the 10 samples, the function will randomly select 5 entries (or rows) from the house_hold DataFrame.

#For each of the 10 samples, the function will randomly select 5 entries from the 'Total Household Income' column of the house_hold DataFrame.
#It calculates the mean (average) of these 5 entries.
#This process is repeated 10 times, each time with a new random sample of 5 entries.
#The function then collects each of these 10 sample means and stores them in a list.

#STORING THE RESULTS: sample_mean_list = ...: The list of sample means returned by the function is stored in the variable sample_mean_list.
#This variable now contains 10 different mean values, 
#each representing the average total household income for a small sample of 5 households from your larger house_hold dataset.

# %%
visual_sample_mean(mean_income,sample_mean_list)
# Out:
# C:\Users\britn\anaconda3\envs\iod\lib\site-packages\ipykernel_launcher.py:9: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   if __name__ == "__main__":

# %%
sample_mean_list = calculate_sample_mean(house_hold, 'Total Household Income', N=1000,  sample_size =15)

# %%
visual_sample_mean(mean_income, sample_mean_list)
# Out:
# C:\Users\britn\anaconda3\envs\iod\lib\site-packages\ipykernel_launcher.py:9: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   if __name__ == "__main__":

# %%
sample_mean_list = calculate_sample_mean(house_hold, 'Total Household Income', N= 1000, sample_size = 50)

# %%
visual_sample_mean(mean_income, sample_mean_list)
# Out:
# C:\Users\britn\anaconda3\envs\iod\lib\site-packages\ipykernel_launcher.py:9: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   if __name__ == "__main__":

# %%
np.mean(sample_mean_list)
# Out:
# 250911.9326

# %%
sample_mean_list
# Out:
# [72545.0,
#  254011.0,
#  513521.4,
#  213981.0,
#  278506.6,
#  172793.4,
#  231340.0,
#  154872.4,
#  239294.2,
#  260395.0]
