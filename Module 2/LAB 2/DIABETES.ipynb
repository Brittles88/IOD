# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
# Out:
# Bad key "text.kerning_factor" on line 4 in
# C:\Users\britn\anaconda3\envs\iod\lib\site-packages\matplotlib\mpl-data\stylelib\_classic_test_patch.mplstyle.
# You probably need to get an updated matplotlibrc file from
# https://github.com/matplotlib/matplotlib/blob/v3.1.3/matplotlibrc.template
# or from the matplotlib source distribution

# %%
# %pwd
# Out:
# 'C:\\Users\\britn\\OneDrive\\Documents\\IOD\\Module 2\\LAB 2'

# %%
df = pd.read_csv('../../DATA/diabetes.csv')

# %%
df
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Pregnancies               768 non-null    int64
#  1   Glucose                   768 non-null    int64
#  2   BloodPressure             768 non-null    int64
#  3   SkinThickness             768 non-null    int64
#  4   Insulin                   768 non-null    int64
#  5   BMI                       768 non-null    float64
#  6   DiabetesPedigreeFunction  768 non-null    float64
#  7   Age                       768 non-null    int64
#  8   Outcome                   768 non-null    int64
# dtypes: float64(2), int64(7)
# memory usage: 54.1 KB

# %%
df.Age.value_counts(ascending = False)
# bins = are half closed interval which means each bin has left endpoint but excludes the right endpoint.
#normalize = indicating the proportion of each age in the dataset. For instance: 22 years old constiutes 9% of the data
#dropna = False - includes NAN values
# Out:
# 22    72
# 21    63
# 25    48
# 24    46
# 23    38
# 28    35
# 26    33
# 27    32
# 29    29
# 31    24
# 41    22
# 30    21
# 37    19
# 42    18
# 33    17
# 38    16
# 36    16
# 32    16
# 45    15
# 34    14
# 46    13
# 43    13
# 40    13
# 39    12
# 35    10
# 50     8
# 51     8
# 52     8
# 44     8
# 58     7
# 47     6
# 54     6
# 49     5
# 48     5
# 57     5
# 53     5
# 60     5
# 66     4
# 63     4
# 62     4
# 55     4
# 67     3
# 56     3
# 59     3
# 65     3
# 69     2
# 61     2
# 72     1
# 81     1
# 64     1
# 70     1
# 68     1
# Name: Age, dtype: int64

# %%
df.Pregnancies.value_counts(ascending = False)
# Out:
# 1     135
# 0     111
# 2     103
# 3      75
# 4      68
# 5      57
# 6      50
# 7      45
# 8      38
# 9      28
# 10     24
# 11     11
# 13     10
# 12      9
# 14      2
# 15      1
# 17      1
# Name: Pregnancies, dtype: int64

# %%
sns.pairplot(data=df, hue = 'Age')

# %%
sns.boxplot(data= df, x='Outcome', y='BMI')

# %%
sns.boxplot(data=df, x='Outcome', y='Pregnancies')

# %%
sns.scatterplot(data=df,x='BMI', y='Pregnancies')
plt.title('Pregnancies vs. BMI')
# Out:
# Text(0.5, 1.0, 'Pregnancies vs. BMI')

# %%
sns.barplot(data=df, x='Pregnancies', y='Glucose', palette = 'Set1', hue = 'Outcome');

# %%
sns.color_palette('Set3')
# Out:
# [(0.5529411764705883, 0.8274509803921568, 0.7803921568627451),
#  (1.0, 1.0, 0.7019607843137254),
#  (0.7450980392156863, 0.7294117647058823, 0.8549019607843137),
#  (0.984313725490196, 0.5019607843137255, 0.4470588235294118),
#  (0.5019607843137255, 0.6941176470588235, 0.8274509803921568),
#  (0.9921568627450981, 0.7058823529411765, 0.3843137254901961),
#  (0.7019607843137254, 0.8705882352941177, 0.4117647058823529),
#  (0.9882352941176471, 0.803921568627451, 0.8980392156862745),
#  (0.8509803921568627, 0.8509803921568627, 0.8509803921568627),
#  (0.7372549019607844, 0.5019607843137255, 0.7411764705882353),
#  (0.8, 0.9215686274509803, 0.7725490196078432),
#  (1.0, 0.9294117647058824, 0.43529411764705883)]

# %%
df.Outcome.value_counts().plot(kind='bar');
plt.title('Outcome Distribution');

# %%
grouped = df.groupby('BMI')['Outcome'].max().sort_index()

# %%
grouped
# Out:
# BMI
# 0.0     1
# 18.2    0
# 18.4    0
# 19.1    0
# 19.3    0
#        ..
# 53.2    1
# 55.0    1
# 57.3    0
# 59.4    1
# 67.1    1
# Name: Outcome, Length: 248, dtype: int64

# %%
df
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %%
df.agg("mean",axis = 0)
# Out:
# Pregnancies                   3.845052
# Glucose                     120.894531
# BloodPressure                69.105469
# SkinThickness                20.536458
# Insulin                      79.799479
# BMI                          31.992578
# DiabetesPedigreeFunction      0.471876
# Age                          33.240885
# Outcome                       0.348958
# dtype: float64

# %%
df.corr()
# Out:
#                           Pregnancies   Glucose  BloodPressure  SkinThickness  \
# Pregnancies                  1.000000  0.129459       0.141282      -0.081672
# Glucose                      0.129459  1.000000       0.152590       0.057328
# BloodPressure                0.141282  0.152590       1.000000       0.207371
# SkinThickness               -0.081672  0.057328       0.207371       1.000000
# Insulin                     -0.073535  0.331357       0.088933       0.436783
# BMI                          0.017683  0.221071       0.281805       0.392573
# DiabetesPedigreeFunction    -0.033523  0.137337       0.041265       0.183928
# Age                          0.544341  0.263514       0.239528      -0.113970
# Outcome                      0.221898  0.466581       0.065068       0.074752
#
#                            Insulin       BMI  DiabetesPedigreeFunction  \
# Pregnancies              -0.073535  0.017683                 -0.033523
# ...

# %%
df.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   768.000000  768.000000     768.000000     768.000000  768.000000
# mean      3.845052  120.894531      69.105469      20.536458   79.799479
# std       3.369578   31.972618      19.355807      15.952218  115.244002
# min       0.000000    0.000000       0.000000       0.000000    0.000000
# 25%       1.000000   99.000000      62.000000       0.000000    0.000000
# 50%       3.000000  117.000000      72.000000      23.000000   30.500000
# 75%       6.000000  140.250000      80.000000      32.000000  127.250000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  768.000000                768.000000  768.000000  768.000000
# mean    31.992578                  0.471876   33.240885    0.348958
# std      7.884160                  0.331329   11.760232    0.476951
# ...

# %%
df.agg(['sum', 'min','mean'])
# Out:
#       Pregnancies       Glucose  BloodPressure  SkinThickness       Insulin  \
# sum   2953.000000  92847.000000   53073.000000   15772.000000  61286.000000
# min      0.000000      0.000000       0.000000       0.000000      0.000000
# mean     3.845052    120.894531      69.105469      20.536458     79.799479
#
#                BMI  DiabetesPedigreeFunction           Age     Outcome
# sum   24570.300000                362.401000  25529.000000  268.000000
# min       0.000000                  0.078000     21.000000    0.000000
# mean     31.992578                  0.471876     33.240885    0.348958

# %%
df.agg({'Pregnancies' : ['sum', 'min'], 'BMI' : ['min', 'max']})
# Out:
#      Pregnancies   BMI
# sum       2953.0   NaN
# min          0.0   0.0
# max          NaN  67.1

# %%
glucose = df.groupby('Glucose')['Age'].agg([min,max])

# %%
glucose
# Out:
#          min  max
# Glucose
# 0         21   41
# 44        36   36
# 56        22   22
# 57        41   67
# 61        46   46
# ...      ...  ...
# 195       31   55
# 196       29   57
# 197       31   62
# 198       28   28
# 199       22   22
#
# [136 rows x 2 columns]

# %%
glucose.sort_values(by= ['min','max'], ascending = False)
# Out:
#          min  max
# Glucose
# 190       66   66
# 176       52   58
# 161       47   65
# 61        46   46
# 67        46   46
# ...      ...  ...
# 131       21   32
# 73        21   27
# 71        21   26
# 113       21   25
# 177       21   21
#
# [136 rows x 2 columns]

# %%
df.apply('sqrt')
# Out:
#      Pregnancies    Glucose  BloodPressure  SkinThickness    Insulin  \
# 0       2.449490  12.165525       8.485281       5.916080   0.000000
# 1       1.000000   9.219544       8.124038       5.385165   0.000000
# 2       2.828427  13.527749       8.000000       0.000000   0.000000
# 3       1.000000   9.433981       8.124038       4.795832   9.695360
# 4       0.000000  11.704700       6.324555       5.916080  12.961481
# ..           ...        ...            ...            ...        ...
# 763     3.162278  10.049876       8.717798       6.928203  13.416408
# 764     1.414214  11.045361       8.366600       5.196152   0.000000
# 765     2.236068  11.000000       8.485281       4.795832  10.583005
# 766     1.000000  11.224972       7.745967       0.000000   0.000000
# 767     1.000000   9.643651       8.366600       5.567764   0.000000
#
#           BMI  DiabetesPedigreeFunction       Age  Outcome
# 0    5.796551                  0.791833  7.071068      1.0
# ...

# %%
df.apply('sum', axis='rows')
# Out:
# Pregnancies                  2953.000
# Glucose                     92847.000
# BloodPressure               53073.000
# SkinThickness               15772.000
# Insulin                     61286.000
# BMI                         24570.300
# DiabetesPedigreeFunction      362.401
# Age                         25529.000
# Outcome                       268.000
# dtype: float64

# %%
df.head(5)
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
df.apply('sum', axis='columns')
# Out:
# 0      346.227
# 1      238.951
# 2      311.972
# 3      322.267
# 4      459.388
#         ...
# 763    511.071
# 764    285.140
# 765    389.445
# 766    265.449
# 767    248.715
# Length: 768, dtype: float64

# %%
df.add(0.1)
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6.1    148.1           72.1           35.1      0.1  33.7
# 1            1.1     85.1           66.1           29.1      0.1  26.7
# 2            8.1    183.1           64.1            0.1      0.1  23.4
# 3            1.1     89.1           66.1           23.1     94.1  28.2
# 4            0.1    137.1           40.1           35.1    168.1  43.2
# ..           ...      ...            ...            ...      ...   ...
# 763         10.1    101.1           76.1           48.1    180.1  33.0
# 764          2.1    122.1           70.1           27.1      0.1  36.9
# 765          5.1    121.1           72.1           23.1    112.1  26.3
# 766          1.1    126.1           60.1            0.1      0.1  30.2
# 767          1.1     93.1           70.1           31.1      0.1  30.5
#
#      DiabetesPedigreeFunction   Age  Outcome
# 0                       0.727  50.1      1.1
# ...

# %%
df.groupby('Insulin').Glucose.mean().sort_index()
# Out:
# Insulin
# 0      119.409091
# 14     180.000000
# 15      68.000000
# 16      88.000000
# 18      91.000000
#           ...
# 579    172.000000
# 600    124.000000
# 680    165.000000
# 744    197.000000
# 846    189.000000
# Name: Glucose, Length: 186, dtype: float64

# %%
df.groupby(['Glucose','Pregnancies']).size().sort_values(ascending = False )
# Out:
# Glucose  Pregnancies
# 100      2              5
# 97       1              5
# 108      2              5
# 112      2              5
# 102      0              5
#                        ..
# 111      0              1
# 110      8              1
#          5              1
#          2              1
# 199      1              1
# Length: 536, dtype: int64

# %%
df[(df.Glucose == 100) & (df.Pregnancies == 2)]
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 70             2      100             66             20       90  32.9
# 87             2      100             68             25       71  38.5
# 163            2      100             64             23        0  29.7
# 275            2      100             70             52       57  40.5
# 454            2      100             54             28      105  37.8
#
#      DiabetesPedigreeFunction  Age  Outcome
# 70                      0.867   28        1
# 87                      0.324   26        0
# 163                     0.368   21        0
# 275                     0.677   25        0
# 454                     0.498   24        0

# %%
df[(df.SkinThickness == 20) & (df.Age == 28)]
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 70             2      100             66             20       90  32.9
# 621            2       92             76             20        0  24.2
#
#      DiabetesPedigreeFunction  Age  Outcome
# 70                      0.867   28        1
# 621                     1.698   28        0

# %%
df.groupby(['SkinThickness','Age']).size().sort_values(ascending = False)
# Out:
# SkinThickness  Age
# 0              21     12
#                27     12
#                22     12
#                29     11
#                31     10
#                       ..
# 26             24      1
#                23      1
#                21      1
# 25             46      1
# 99             62      1
# Length: 442, dtype: int64

# %%
cool = df[(df.SkinThickness == 0) & (df.Age == 21)]

# %%
cool
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 60             2       84              0              0        0   0.0
# 90             1       80             55              0        0  19.1
# 102            0      125             96              0        0  22.5
# 190            3      111             62              0        0  22.6
# 196            1      105             58              0        0  24.3
# 268            0      102             52              0        0  25.1
# 354            3       90             78              0        0  42.7
# 571            2      130             96              0        0  22.6
# 577            2      118             80              0        0  42.9
# 624            2      108             64              0        0  30.8
# 626            0      125             68              0        0  24.7
# 627            0      132             78              0        0  32.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# ...

# %%
len(cool)
# Out:
# 12

# %%
df.iloc[1]
# Out:
# Pregnancies                  1.000
# Glucose                     85.000
# BloodPressure               66.000
# SkinThickness               29.000
# Insulin                      0.000
# BMI                         26.600
# DiabetesPedigreeFunction     0.351
# Age                         31.000
# Outcome                      0.000
# Name: 1, dtype: float64

# %%
df.Pregnancies.iloc[1]
# Out:
# 1

# %%
df.iloc[2:5]
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
index = [1, 3, 4 , 9, 20]
lists = ['Glucose', 'Insulin','BloodPressure']
df.loc[index,lists]
# Out:
#     Glucose  Insulin  BloodPressure
# 1        85        0             66
# 3        89       94             66
# 4       137      168             40
# 9       125        0             96
# 20      126      235             88

# %%
df[(df.Age.isin([21,22,23,24,25])) & (df.Outcome == 1)]
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 45             0      180             66             39        0  42.0
# 109            0       95             85             25       36  37.4
# 110            3      171             72             33      135  33.3
# 120            0      162             76             56      100  53.2
# 124            0      113             76              0        0  33.3
# 189            5      139             80             35      160  31.6
# 197            3      107             62             13       48  22.9
# 213            0      140             65             26      130  42.6
# 216            5      109             62             41      129  35.8
# 220            0      177             60             29      478  34.6
# 227            3      162             52             38        0  37.2
# 230            4      142             86              0        0  44.0
# ...

# %%
df[(df.BMI >= 30) & (df.Age >= 50)]
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 8              2      197             70             45      543  30.5
# 13             1      189             60             23      846  30.1
# 21             8       99             84              0        0  35.4
# 24            11      143             94             33      146  36.6
# 30             5      109             75             26        0  36.0
# 39             4      111             72             47      207  37.1
# 43             9      171            110             24      240  45.4
# 53             8      176             90             34      300  33.7
# 67             2      109             92              0        0  42.7
# 115            4      146             92              0        0  31.2
# 148            5      147             78              0        0  33.7
# ...

# %%
len(df[(df.BMI >= 30) & (df.Age >= 50)])
# Out:
# 47

# %%
df.BMI.max()
# Out:
# 67.1

# %%
df.BMI.min()
# Out:
# 0.0

# %%
df.BMI.mean()
# Out:
# 31.992578124999977

# %%
df[(df.BMI >= 60)]
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 177            0      129            110             46      130  67.1
#
#      DiabetesPedigreeFunction  Age  Outcome
# 177                     0.319   26        1

# %%
df.Age.unique()
# Out:
# array([50, 31, 32, 21, 33, 30, 26, 29, 53, 54, 34, 57, 59, 51, 27, 41, 43,
#        22, 38, 60, 28, 45, 35, 46, 56, 37, 48, 40, 25, 24, 58, 42, 44, 39,
#        36, 23, 61, 69, 62, 55, 65, 47, 52, 66, 49, 63, 67, 72, 81, 64, 70,
#        68], dtype=int64)

# %%
df.columns
# Out:
# Index(['Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness', 'Insulin',
#        'BMI', 'DiabetesPedigreeFunction', 'Age', 'Outcome'],
#       dtype='object')

# %%
print(f"min of Insulin: {df.Insulin.min()} \n max of Insulin: {df.Insulin.max()}")
# Out:
# min of Insulin: 0
#  max of Insulin: 846

# %%
print(f"min of Skin Thickness: {df.SkinThickness.min()} \n max of Skin Thickness: {df.SkinThickness.max()}")
# Out:
# min of Skin Thickness: 0
#  max of Skin Thickness: 99

# %%
print(f"Glucose has a min of {df.SkinThickness.min()} and a max of {df.Glucose.max()}")
# Out:
# Glucose has a min of 0 and a max of 199

# %%
print(f"The youngest age in this dataset is {df.Age.min()} and the oldest age in this dataset is {df.Age.max()}")
# Out:
# The youngest age in this dataset is 21 and the oldest age in this dataset is 81
