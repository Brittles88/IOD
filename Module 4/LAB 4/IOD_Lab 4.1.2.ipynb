# %% [markdown]
# <div>
# <img src=https://www.institutedata.com/wp-content/uploads/2019/10/iod_h_tp_primary_c.svg width="300">
# </div>

# %% [markdown]
# # Lab 4.1.2 Linear Regression

# %% [markdown]
# ## Prediction of House Price Using Linear Regression

# %% [markdown]
# ### Data
#
# The Sacramento real estate transactions file is a list of 985 real estate transactions in the Sacramento area reported over a five-day period, as reported by the Sacramento Bee.

# %%
import pandas as pd
import numpy as np
import pandas as pd

# %matplotlib inline
# Out:
# Bad key "text.kerning_factor" on line 4 in
# C:\Users\britn\anaconda3\envs\iod\lib\site-packages\matplotlib\mpl-data\stylelib\_classic_test_patch.mplstyle.
# You probably need to get an updated matplotlibrc file from
# https://github.com/matplotlib/matplotlib/blob/v3.1.3/matplotlibrc.template
# or from the matplotlib source distribution

# %% [markdown]
# ### 1. Explore Data

# %% [markdown]
# Perform EDA on this dataset. Find Dependent and Independent Variables to predict house price.

# %%
# Read CSV
house_csv = "../../data/Sacramento_transactions.csv"
df = pd.read_csv('../../DATA/Sacramento_transactions.csv')

# %%
df
# Out:
#                   street             city    zip state  beds  baths  sq__ft  \
# 0           3526 HIGH ST       SACRAMENTO  95838    CA     2      1     836
# 1            51 OMAHA CT       SACRAMENTO  95823    CA     3      1    1167
# 2         2796 BRANCH ST       SACRAMENTO  95815    CA     2      1     796
# 3       2805 JANETTE WAY       SACRAMENTO  95815    CA     2      1     852
# 4        6001 MCMAHON DR       SACRAMENTO  95824    CA     2      1     797
# ..                   ...              ...    ...   ...   ...    ...     ...
# 980   9169 GARLINGTON CT       SACRAMENTO  95829    CA     4      3    2280
# 981      6932 RUSKUT WAY       SACRAMENTO  95823    CA     3      2    1477
# 982    7933 DAFFODIL WAY   CITRUS HEIGHTS  95610    CA     3      2    1216
# 983     8304 RED FOX WAY        ELK GROVE  95758    CA     4      2    1685
# 984  3882 YELLOWSTONE LN  EL DORADO HILLS  95762    CA     3      2    1362
#
#             type                     sale_date   price   latitude   longitude
# 0    Residential  Wed May 21 00:00:00 EDT 2008   59222  38.631913 -121.434879
# 1    Residential  Wed May 21 00:00:00 EDT 2008   68212  38.478902 -121.431028
# 2    Residential  Wed May 21 00:00:00 EDT 2008   68880  38.618305 -121.443839
# 3    Residential  Wed May 21 00:00:00 EDT 2008   69307  38.616835 -121.439146
# 4    Residential  Wed May 21 00:00:00 EDT 2008   81900  38.519470 -121.435768
# ..           ...                           ...     ...        ...         ...
# 980  Residential  Thu May 15 00:00:00 EDT 2008  232425  38.457679 -121.359620
# 981  Residential  Thu May 15 00:00:00 EDT 2008  234000  38.499893 -121.458890
# 982  Residential  Thu May 15 00:00:00 EDT 2008  235000  38.708824 -121.256803
# 983  Residential  Thu May 15 00:00:00 EDT 2008  235301  38.417000 -121.397424
# 984  Residential  Thu May 15 00:00:00 EDT 2008  235738  38.655245 -121.075915
#
# [985 rows x 12 columns]

# %%
df.shape
# Out:
# (985, 12)

# %%
df.head()
# Out:
#              street        city    zip state  beds  baths  sq__ft  \
# 0      3526 HIGH ST  SACRAMENTO  95838    CA     2      1     836
# 1       51 OMAHA CT  SACRAMENTO  95823    CA     3      1    1167
# 2    2796 BRANCH ST  SACRAMENTO  95815    CA     2      1     796
# 3  2805 JANETTE WAY  SACRAMENTO  95815    CA     2      1     852
# 4   6001 MCMAHON DR  SACRAMENTO  95824    CA     2      1     797
#
#           type                     sale_date  price   latitude   longitude
# 0  Residential  Wed May 21 00:00:00 EDT 2008  59222  38.631913 -121.434879
# 1  Residential  Wed May 21 00:00:00 EDT 2008  68212  38.478902 -121.431028
# 2  Residential  Wed May 21 00:00:00 EDT 2008  68880  38.618305 -121.443839
# 3  Residential  Wed May 21 00:00:00 EDT 2008  69307  38.616835 -121.439146
# 4  Residential  Wed May 21 00:00:00 EDT 2008  81900  38.519470 -121.435768

# %%
df.tail()
# Out:
#                   street             city    zip state  beds  baths  sq__ft  \
# 980   9169 GARLINGTON CT       SACRAMENTO  95829    CA     4      3    2280
# 981      6932 RUSKUT WAY       SACRAMENTO  95823    CA     3      2    1477
# 982    7933 DAFFODIL WAY   CITRUS HEIGHTS  95610    CA     3      2    1216
# 983     8304 RED FOX WAY        ELK GROVE  95758    CA     4      2    1685
# 984  3882 YELLOWSTONE LN  EL DORADO HILLS  95762    CA     3      2    1362
#
#             type                     sale_date   price   latitude   longitude
# 980  Residential  Thu May 15 00:00:00 EDT 2008  232425  38.457679 -121.359620
# 981  Residential  Thu May 15 00:00:00 EDT 2008  234000  38.499893 -121.458890
# 982  Residential  Thu May 15 00:00:00 EDT 2008  235000  38.708824 -121.256803
# 983  Residential  Thu May 15 00:00:00 EDT 2008  235301  38.417000 -121.397424
# 984  Residential  Thu May 15 00:00:00 EDT 2008  235738  38.655245 -121.075915

# %%
df.isnull().sum()
# Out:
# street       0
# city         0
# zip          0
# state        0
# beds         0
# baths        0
# sq__ft       0
# type         0
# sale_date    0
# price        0
# latitude     0
# longitude    0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 985 entries, 0 to 984
# Data columns (total 12 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   street     985 non-null    object
#  1   city       985 non-null    object
#  2   zip        985 non-null    int64
#  3   state      985 non-null    object
#  4   beds       985 non-null    int64
#  5   baths      985 non-null    int64
#  6   sq__ft     985 non-null    int64
#  7   type       985 non-null    object
#  8   sale_date  985 non-null    object
#  9   price      985 non-null    int64
#  10  latitude   985 non-null    float64
#  11  longitude  985 non-null    float64
# dtypes: float64(2), int64(5), object(5)
# memory usage: 92.5+ KB

# %%
df.describe().T
# Out:
#            count           mean            std           min            25%  \
# zip        985.0   95750.697462      85.176072  95603.000000   95660.000000
# beds       985.0       2.911675       1.307932      0.000000       2.000000
# baths      985.0       1.776650       0.895371      0.000000       1.000000
# sq__ft     985.0    1314.916751     853.048243      0.000000     952.000000
# price      985.0  234144.263959  138365.839085   1551.000000  145000.000000
# latitude   985.0      38.607732       0.145433     38.241514      38.482717
# longitude  985.0    -121.355982       0.138278   -121.551704    -121.446127
#
#                      50%            75%            max
# zip         95762.000000   95828.000000   95864.000000
# beds            3.000000       4.000000       8.000000
# baths           2.000000       2.000000       5.000000
# sq__ft       1304.000000    1718.000000    5822.000000
# price      213750.000000  300000.000000  884790.000000
# latitude       38.626582      38.695589      39.020808
# longitude    -121.376220    -121.295778    -120.597599

# %%
df[df['baths'] == 0]
# Out:
#                        street             city    zip state  beds  baths  \
# 73              17 SERASPI CT       SACRAMENTO  95834    CA     0      0
# 89           2866 KARITSA AVE       SACRAMENTO  95833    CA     0      0
# 100     12209 CONSERVANCY WAY   RANCHO CORDOVA  95742    CA     0      0
# 121       5337 DUSTY ROSE WAY   RANCHO CORDOVA  95742    CA     0      0
# 126       2115 SMOKESTACK WAY       SACRAMENTO  95833    CA     0      0
# ..                        ...              ...    ...   ...   ...    ...
# 901  1530 TOPANGA LN Unit 204          LINCOLN  95648    CA     0      0
# 917            501 POPLAR AVE  WEST SACRAMENTO  95691    CA     0      0
# 934  1550 TOPANGA LN Unit 207          LINCOLN  95648    CA     0      0
# 947     1525 PENNSYLVANIA AVE  WEST SACRAMENTO  95691    CA     0      0
# 970             3557 SODA WAY       SACRAMENTO  95834    CA     0      0
#
#      sq__ft         type                     sale_date   price   latitude  \
# 73        0  Residential  Wed May 21 00:00:00 EDT 2008  206000  38.631481
# 89        0  Residential  Wed May 21 00:00:00 EDT 2008  244500  38.626671
# 100       0  Residential  Wed May 21 00:00:00 EDT 2008  263500  38.553867
# 121       0  Residential  Wed May 21 00:00:00 EDT 2008  320000  38.528575
# 126       0  Residential  Wed May 21 00:00:00 EDT 2008  339500  38.602416
# ..      ...          ...                           ...     ...        ...
# 901       0        Condo  Thu May 15 00:00:00 EDT 2008  138000  38.884150
# 917       0  Residential  Thu May 15 00:00:00 EDT 2008  165000  38.584526
# 934       0        Condo  Thu May 15 00:00:00 EDT 2008  188000  38.884170
# 947       0  Residential  Thu May 15 00:00:00 EDT 2008  200100  38.569943
# 970       0  Residential  Thu May 15 00:00:00 EDT 2008  224000  38.631026
#
#       longitude
# 73  -121.501880
# 89  -121.525970
# 100 -121.219141
# 121 -121.228600
# 126 -121.542965
# ..          ...
# 901 -121.270277
# 917 -121.534609
# 934 -121.270222
# 947 -121.527539
# 970 -121.501879
#
# [108 rows x 12 columns]

# %%
df['type'].value_counts().plot(kind='bar')

# %%
df['city'].value_counts().sort_values().plot(kind='barh',figsize=(15,10));

# %%
df.loc[df['beds'] == 0, 'type'] = 'Plot'

# %%
df.head(1)
# Out:
#          street        city    zip state  beds  baths  sq__ft         type  \
# 0  3526 HIGH ST  SACRAMENTO  95838    CA     2      1     836  Residential
#
#                       sale_date  price   latitude   longitude
# 0  Wed May 21 00:00:00 EDT 2008  59222  38.631913 -121.434879

# %%
df['state'].value_counts().plot(kind='bar');

# %%
import folium

#make an empty map
m = folium.Map(location=[38.575764,-121.478851], tiles="OpenStreetMap", zoom_start=10)

# Add circles or markers on the map
for i in range(0, len(df.head(1000))):
    folium.Marker(location=[df.iloc[i]['latitude'], df.iloc[i]['longitude']]).add_to(m)
    
display(m)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_7cdc3149d7d14ecad89b678b891ca111 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_7cdc3149d7d14ecad89b678b891ca111&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_7cdc3149d7d14ecad89b678b891ca111 = L.map(
#                 &quot;map_7cdc3149d7d14ecad89b678b891ca111&quot;,
#                 {
#                     center: [38.575764, -121.478851],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_b6722416d6150dfe2c63c8a3617b07a1 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_7cdc3149d7d14ecad89b678b891ca111);
#
#
#             var marker_cedf8484779a777c8fbec56b651ffb30 = L.marker(
#                 [38.631913, -121.434879],
#                 {}
#             ).addTo(map_7cdc3149d7d14ecad89b678b891ca111);
#
#
#             var marker_a100431a5e5a4db17979f4cae8f2e32b = L.marker(
#                 [38.478902, -121.431028],
#                 {}
#             ).addTo(map_7cdc3149d7d14ecad89b678b891ca111);
#
#
#             var marker_5e6ccddf0ddd6ffd131ba26e61d02858 = L.marker(
#                 [38.618305, -121.443839],
#                 {}
#             ).addTo(map_7cdc3149d7d14ecad89b678b891ca111);
#
#
#             var marker_1cd5a16165b8c1a4963169485ecb5270 = L.marker(
#                 [38.616835, -121.439146],
#                 {}
#             ).addTo(map_7cdc3149d7d14ecad89b678b891ca111);
#
#
#             var marker_78ed63a4adb7f76a876f30c74cb8ec39 = L.marker(
#                 [38.51947, -121.435768],
#                 {}
#             ).addTo(map_7cdc3149d7d14ecad89b678b891ca111);
#
#
#             var marker_1e84fb96fa0a7c42a6dbc942dcbe35dd = L.marker(
#                 [38.662595, -121.327813],
#                 {}
#             ).addTo(map_7cdc3149d7d14ecad89b678b891ca111);
#
#
#             var marker_1b7d6cd6bc9e6f5dd1d39f3275129f30 = L.marker(
#                 [38.681659, -121.351705],
#                 {}
#             ).addTo(map_7cdc3149d7d14ecad89b678b891ca111);
#
#
#             var marker_e7140fb8cb20c1a9b82360ab82f4cea9 = L.marker(
#                 [38.535092, -121.481367],
#                 {}
#             ).addTo(map_7cdc3149d7d14ecad89b678b891ca111);
#
#
#             var marker_4c7dcb1ea80786c6638f88a15c7c36d3 = L.marker(
#                 [38.621188, -121.270555],
#                 {}
#             ).addTo(map_7cdc3149d7d14ecad89b678b891ca111);
#
#
#             var marker_a82f1f78cb260a9b1d93fcc1446044fb = L.marker(
#                 [38.700909, -121.442979],
#                 {}
#             ).addTo(map_7cdc3149d7d14ecad89b678b891ca111);
#
#
#             var marker_62cb7a9fa39fc4b18421594f8fd324c8 = L.marker(
#                 [38.637663, -121.45152],
#                 {}
#             ).addTo(map_7cdc3149d7d14ecad89b678b891ca111);
#
#
#             var marker_5d6fd82b03adf543ee838eb48b2f583e = L.marker(
#                 [38.470746, -121.458918],
#                 {}
#             ).addTo(map_7cdc3149d7d14ecad89b678b891ca111);
#
#
#             var marker_2775f1b48e6547f3a42421a3cf578ab2 = L.marker(
#                 [38.618698, -121.435833],
#                 {}
#             ).addTo(map_7cdc3149d7d14ecad89b678b891ca111);
#
#
#             var marker_ee5e2b5dfcf0f3ca6482d2f16d9285dc = L.marker(
#                 [38.482215, -121.492603],
#                 {}
#             ).addTo(map_7cdc3149d7d14ecad89b678b891ca111);
#
#
#             var marker_ac33a3d370e57409b6e45bcb51e8da28 = L.marker(
#                 [38.672914, -121.35934],
#                 {}
#             ).addTo(map_7cdc3149d7d14ecad89b678b891ca111);
#
#
#             var marker_6001aded7f0e9e8f5a0b3c7300b54c11 = L.marker(
#                 [38.700051, -121.351278],
#                 {}
#             ).addTo(map_7cdc3149d7d14ecad89b678b891ca111);
#
#
#             var marker_5429388284af955c40c95ef33bf4888e = L.marker(
#                 [38.689591, -121.452239],
#                 {}
#             ).addTo(map_7cdc3149d7d14ecad89b678b891ca111);
#
#
#             var marker_a8864715fbc7b13b6960b0a34bc23492 = L.marker(
#                 [38.679776, -121.314089],
#                 {}
#             ).addTo(map_7cdc3149d7d14ecad89b678b891ca111);
#
#
#             var marker_d367e4e90e6d5ce0a2a4cc46b3f88334 = L.marker(
#                 [38.612099, -121.469095],
#                 {}
#             ).addTo(map_7cdc3149d7d14ecad89b678b891ca111);
#
#
#             var marker_34e64c91399c2a48ae1f0d2e90699c1e = L.marker(
#                 [38.689999, -121.46322],
#                 {}
#             ).addTo(map_7cdc3149d7d14ecad89b678b891ca111);
#
#
#             var marker_f537b0736d5c0db4319417c

# %% [markdown]
# ### 2. Predict Price

# %% [markdown]
# We are going to predict `price` from available information.

# %% [markdown]
# #### 2.1 What is the Target Variable? Why?

# %%
# ANSWER
#Price is a target variable due to other predictor variables

# %% [markdown]
# #### 2.2 List all possible variables which might be Independent/Predictor variable.

# %%
# ANSWER
Y = df['price']
X = df['beds']

# %%
import matplotlib.pyplot as plt

# %%
def draw_scatter_plot(X, Y):
    fig = plt.figure(figsize=(15,7))
    ax = plt.gca()
    ax.scatter(X, Y, c='b')
    plt.show();

# %%
#beds
draw_scatter_plot(df['beds'], df['price'])

# %%
#baths
draw_scatter_plot(df['baths'], df['price'])

# %%
#sq__ft
draw_scatter_plot(df['sq__ft'], df['price'])

# %% [markdown]
# #### 2.3 Find correlation between variables
#
# Find correlation between variables. Which is the best predictor? Why? State your reason.

# %%
# ANSWER
df.corr()
# Out:
#                 zip      beds     baths    sq__ft     price  latitude  \
# zip        1.000000  0.125319  0.069165  0.130108 -0.093353 -0.290389
# beds       0.125319  1.000000  0.839650  0.684041  0.342024 -0.291307
# baths      0.069165  0.839650  1.000000  0.665690  0.416208 -0.235792
# sq__ft     0.130108  0.684041  0.665690  1.000000  0.333897 -0.383274
# price     -0.093353  0.342024  0.416208  0.333897  1.000000 -0.039573
# latitude  -0.290389 -0.291307 -0.235792 -0.383274 -0.039573  1.000000
# longitude -0.539904 -0.053993  0.016582 -0.177742  0.284485  0.387925
#
#            longitude
# zip        -0.539904
# beds       -0.053993
# baths       0.016582
# sq__ft     -0.177742
# price       0.284485
# latitude    0.387925
# longitude   1.000000

# %%
#sq__ft is the best predictor, has a greater relationship with price than bed and baths

# %% [markdown]
# #### 2.4 Find Coefficient and Intercept using Linear Regression
#
# Using LinearRegression of sklearn.linear_model package find Coefficient and Intercept.
#
# Create an instance of LinearRegression.
#
# Explore following methods:
#
# - fit
# - predict
# - score

# %%
# !pip install scikit-learn
# Out:
# Collecting scikit-learn
#   Downloading scikit_learn-1.0.2-cp37-cp37m-win_amd64.whl (7.1 MB)
#      ---------------------------------------- 7.1/7.1 MB 6.7 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.14.6 in c:\users\britn\anaconda3\envs\iod\lib\site-packages (from scikit-learn) (1.21.5)
# Collecting threadpoolctl>=2.0.0
#   Downloading threadpoolctl-3.1.0-py3-none-any.whl (14 kB)
# Collecting joblib>=0.11
#   Downloading joblib-1.3.1-py3-none-any.whl (301 kB)
#      -------------------------------------- 302.0/302.0 kB 6.2 MB/s eta 0:00:00
# Requirement already satisfied: scipy>=1.1.0 in c:\users\britn\anaconda3\envs\iod\lib\site-packages (from scikit-learn) (1.7.3)
# Installing collected packages: threadpoolctl, joblib, scikit-learn
# Successfully installed joblib-1.3.1 scikit-learn-1.0.2 threadpoolctl-3.1.0

# %%
from sklearn.linear_model import LinearRegression

# %% [markdown]
# ##### 2.4.1 Fit predictor and target variables using linear regression

# %%
# ANSWER

X = df['sq__ft'].values.reshape(-1,1)
Y = df['price']

# %%
X = df['sq__ft'].values.reshape(-1,1)
Y = df['price']

linreg = LinearRegression()
linreg.fit(X, Y)

print(linreg.coef_, linreg.intercept_)
# Out:
# [54.15863969] 162930.16140699777

# %% [markdown]
# ##### 2.4.2 Find R Score

# %% [markdown]
# Find $R^2$ Using ```score``` method of Linear Regression.

# %%
# ANSWER
linreg.score(X, Y)
# Out:
# 0.11148717682951437

# %% [markdown]
# ### 3. Splitting Data

# %%
from sklearn.model_selection import train_test_split

# %% [markdown]
# #### 3.1 Create training and testing subsets
#
# Hint: Using `train_test_split` Library.
#
# ```
# X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42)
# ```

# %%
# ANSWER
## Create training and testing subsets
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size = 0.2)

# %% [markdown]
# #### 3.2 Check Shape, Sample of Test Train Data

# %%
# ANSWER
## Check training data
print('X_train is a %s' % type(X_train))
print('X_train has %d rows', X_train.shape[0])
print('')
print('Sample of X_train%s' % ('_'*50))
print(X_train[:10])

print('')
print('y_train is a %s' % type(y_train))
print('y_train has %d rows', y_train.shape)
print('')
print('Sample of y_train%s' % ('_'*50))
print(y_train[:10])
# Out:
# X_train is a <class 'numpy.ndarray'>
# X_train has %d rows 788
#
# Sample of X_train__________________________________________________
# [[   0]
#  [   0]
#  [   0]
#  [2457]
#  [   0]
#  [4400]
#  [   0]
#  [1304]
#  [1520]
#  [1074]]
#
# y_train is a <class 'pandas.core.series.Series'>
# y_train has %d rows (788,)
#
# Sample of y_train__________________________________________________
# 580      4897
# 604     30000
# 554      4897
# 788    312000
# 707    215000
# 864    884790
# 312    438700
# 831    413500
# 116    299000
# 726    233000
# Name: price, dtype: int64

# %%
#About testing data
print('X_train is a %s' % type(X_test))
print('X_train has %d rows', X_test.shape)
print('')
print('Sample of X_train%s' % ('_'*50))
print(X_test[:10])

print('')
print('y_train is a %s' % type(y_test))
print('y_train has %d rows', y_test.shape)
print('')
print('Sample of y_train%s' % ('_'*50))
print(y_test[:10])
# Out:
# X_train is a <class 'numpy.ndarray'>
# X_train has %d rows (197, 1)
#
# Sample of X_train__________________________________________________
# [[ 795]
#  [1888]
#  [1157]
#  [   0]
#  [1922]
#  [1362]
#  [1289]
#  [1627]
#  [1351]
#  [1905]]
#
# y_train is a <class 'pandas.core.series.Series'>
# y_train has %d rows (197,)
#
# Sample of y_train__________________________________________________
# 17     116250
# 797    325000
# 668    180000
# 503    331500
# 481    284686
# 67     194818
# 11     106250
# 140    391000
# 395    158000
# 542    500000
# Name: price, dtype: int64

# %% [markdown]
# #### 3.3 Using Linear Regression Find The Score
#
# 1. Fit model using X_train, y_train
# 2. Find score using X_test, y_test

# %%
# ANSWER
linreg = LinearRegression()
linreg.fit(X_train, y_train)

print(linreg.coef_, linreg.intercept_)
# Out:
# [48.59104494] 173708.70382368844

# %%
# ANSWER
linreg.score(X_test, y_test)
# Out:
# 0.18495760781671022

# %% [markdown]
# ### 4. Predict House Price
#
# Let's assume we have information of following house:
#
# - street:	1140 EDMONTON DR
# - city:	SACRAMENTO
# - zip:	95833
# - state:	CA
# - beds:	3
# - baths:	2
# - sq__ft:	1204
# - type:	Residential
#
# **Predict the price of this house using linear regression model.**

# %%
# ANSWER
linreg.intercept_, linreg.coef_
# Out:
# (173708.70382368844, array([48.59104494]))

# %%
beta0 = linreg.intercept_
beta1 = linreg.coef_
x = 1204

Ypred = beta1 * x + beta0
print('Predicted house price: ', Ypred[0])
# Out:
# Predicted house price:  232212.3219334452

# %%
x = [[1204]]
Ypred = linreg.predict(x)
print('Predicted house price: ', Ypred[0])
# Out:
# Predicted house price:  232212.3219334452

# %% [markdown]
# #### Find the error

# %%
# Predict price from X_test
y_preds = linreg.predict(X_test)

y_preds[:10]
# Out:
# array([212338.58455231, 265448.59667354, 229928.54282119, 173708.70382369,
#        267100.69220156, 239889.70703423, 236342.56075349, 252766.33394377,
#        239355.20553987, 266274.64443755])

# %%
from sklearn.metrics import mean_squared_error

mean_squared_error(y_test, y_preds, squared=True)
# Out:
# 13951412105.42091

# %% [markdown]
# ---
#
#
#
# ---
#
#
#
# > > > > > > > > > © 2023 Institute of Data
#
#
# ---
#
#
#
# ---
